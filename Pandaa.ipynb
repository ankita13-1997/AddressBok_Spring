# %% [markdown]
# <a href="https://colab.research.google.com/github/ankita13-1997/AddressBok_Spring/blob/master/Pandaa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Panda 1

# %%
import pandas as pd

# %%
# !gdown https://drive.google.com/file/d/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# To: /content/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# 91.0kB [00:00, 3.66MB/s]

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2024-10-23 15:53:27--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 74.125.20.138, 74.125.20.100, 74.125.20.139, ...
# Connecting to drive.google.com (drive.google.com)|74.125.20.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download [following]
# --2024-10-23 15:53:28--  https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.20.132, 2607:f8b0:400e:c01::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.20.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [application/octet-stream]
# Saving to: ‘mckinsey.csv’
#
# ...

# %%
df = pd.read_csv('mckinsey.csv')

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.head(8)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945

# %% [markdown]
# operation on coloumns

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.tail(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1694  Zimbabwe  1962     4277736    Africa    52.358  527.272182
# 1695  Zimbabwe  1967     4995432    Africa    53.995  569.795071
# 1696  Zimbabwe  1972     5861135    Africa    55.635  799.362176
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys()
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df['country'].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df[['country', 'life_exp']].head()
# Out:
#        country  life_exp
# 0  Afghanistan    28.801
# 1  Afghanistan    30.332
# 2  Afghanistan    31.997
# 3  Afghanistan    34.020
# 4  Afghanistan    36.088

# %%
#unique entries
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df['country'].value_counts()
# Out:
# country
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: count, Length: 142, dtype: int64

# %%
df.rename({'population':'Population', 'country' : 'Country'}, axis =1)
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename(columns={"country" :"Country"})
# Out:
#           Country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename(columns={"country" :"Country"}, inplace = True)# cahne the df itself

# %%
df
# Out:
#           Country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop('continent', axis=1)
# Out:
#           Country  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
#df.drop('continent', axis=1, inplace = True)

# %%
df['year']+7
# Out:
# 0       1959
# 1       1964
# 2       1969
# 3       1974
# 4       1979
#         ...
# 1699    1994
# 1700    1999
# 1701    2004
# 1702    2009
# 1703    2014
# Name: year, Length: 1704, dtype: int64

# %%
df["years+7"] = df["year"]+7

# %%
df
# Out:
#           Country  year  population continent  life_exp     gdp_cap  years+7
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314     1959
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030     1964
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710     1969
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138     1974
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106     1979
# ...           ...   ...         ...       ...       ...         ...      ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306     1994
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786     1999
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960     2004
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623     2009
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298     2014
#
# [1704 rows x 7 columns]

# %%
df['gdp'] = df['gdp_cap']*df['population']

# %%
df['Country'].head(5)
# Out:
# 1714    Afghanistan
# 1713    Afghanistan
# 1712    Afghanistan
# 1711    Afghanistan
# 1710    Afghanistan
# Name: Country, dtype: object

# %%
df[2:5]
# Out:
#           Country  year  population continent  life_exp     gdp_cap  years+7  \
# 1712  Afghanistan  1962    10267083      Asia    31.997  853.100710     1969
# 1711  Afghanistan  1967    11537966      Asia    34.020  836.197138     1974
# 1710  Afghanistan  1972    13079460      Asia    36.088  739.981106     1979
#
#                gdp
# 1712  8.758856e+09
# 1711  9.648014e+09
# 1710  9.678553e+09

# %% [markdown]
# ROW manupulation

# %%
df.shape
# Out:
# (1704, 8)

# %%
#update index
df.index = [i for i in range(0,1704)]

# %%
df
# Out:
#           Country  year  population continent  life_exp     gdp_cap  years+7  \
# 10    Afghanistan  1952     8425333      Asia    28.801  779.445314     1959
# 11    Afghanistan  1957     9240934      Asia    30.332  820.853030     1964
# 12    Afghanistan  1962    10267083      Asia    31.997  853.100710     1969
# 13    Afghanistan  1967    11537966      Asia    34.020  836.197138     1974
# 14    Afghanistan  1972    13079460      Asia    36.088  739.981106     1979
# ...           ...   ...         ...       ...       ...         ...      ...
# 1709     Zimbabwe  1987     9216418    Africa    62.351  706.157306     1994
# 1710     Zimbabwe  1992    10704340    Africa    60.377  693.420786     1999
# 1711     Zimbabwe  1997    11404948    Africa    46.809  792.449960     2004
# 1712     Zimbabwe  2002    11926563    Africa    39.989  672.038623     2009
# 1713     Zimbabwe  2007    12311143    Africa    43.487  469.709298     2014
#
#                gdp
# 10    6.567086e+09
# ...

# %%
#update index in reverse
df.index = [i for i in range(1714,10, -1)]

# %%
df
# Out:
#           Country  year  population continent  life_exp     gdp_cap  years+7  \
# 1714  Afghanistan  1952     8425333      Asia    28.801  779.445314     1959
# 1713  Afghanistan  1957     9240934      Asia    30.332  820.853030     1964
# 1712  Afghanistan  1962    10267083      Asia    31.997  853.100710     1969
# 1711  Afghanistan  1967    11537966      Asia    34.020  836.197138     1974
# 1710  Afghanistan  1972    13079460      Asia    36.088  739.981106     1979
# ...           ...   ...         ...       ...       ...         ...      ...
# 15       Zimbabwe  1987     9216418    Africa    62.351  706.157306     1994
# 14       Zimbabwe  1992    10704340    Africa    60.377  693.420786     1999
# 13       Zimbabwe  1997    11404948    Africa    46.809  792.449960     2004
# 12       Zimbabwe  2002    11926563    Africa    39.989  672.038623     2009
# 11       Zimbabwe  2007    12311143    Africa    43.487  469.709298     2014
#
#                gdp
# 1714  6.567086e+09
# ...

# %%
sample = df.head()
sample
# Out:
#           Country  year  population continent  life_exp     gdp_cap  years+7  \
# 1714  Afghanistan  1952     8425333      Asia    28.801  779.445314     1959
# 1713  Afghanistan  1957     9240934      Asia    30.332  820.853030     1964
# 1712  Afghanistan  1962    10267083      Asia    31.997  853.100710     1969
# 1711  Afghanistan  1967    11537966      Asia    34.020  836.197138     1974
# 1710  Afghanistan  1972    13079460      Asia    36.088  739.981106     1979
#
#                gdp
# 1714  6.567086e+09
# 1713  7.585449e+09
# 1712  8.758856e+09
# 1711  9.648014e+09
# 1710  9.678553e+09

# %%
sample.index = ['q','w', 'e', 'r', 't']
sample
# Out:
#        Country  year  population continent  life_exp     gdp_cap  years+7  \
# q  Afghanistan  1952     8425333      Asia    28.801  779.445314     1959
# w  Afghanistan  1957     9240934      Asia    30.332  820.853030     1964
# e  Afghanistan  1962    10267083      Asia    31.997  853.100710     1969
# r  Afghanistan  1967    11537966      Asia    34.020  836.197138     1974
# t  Afghanistan  1972    13079460      Asia    36.088  739.981106     1979
#
#             gdp
# q  6.567086e+09
# w  7.585449e+09
# e  8.758856e+09
# r  9.648014e+09
# t  9.678553e+09

# %%
df['Country'][11]
# Out:
# 'Afghanistan'

# %%
df.loc[11]
# Out:
# Country             Afghanistan
# year                       1957
# population              9240934
# continent                  Asia
# life_exp                 30.332
# gdp_cap               820.85303
# years+7                    1964
# gdp           7585448670.233646
# Name: 11, dtype: object

# %%
df.loc[15: 21]
# Out:
#     Country  year  population continent  life_exp      gdp_cap  years+7  \
# 15  Albania  1967     1984060    Europe    66.220  2760.196931     1974
# 16  Albania  1972     2263554    Europe    67.690  3313.422188     1979
# 17  Albania  1977     2509048    Europe    68.930  3533.003910     1984
# 18  Albania  1982     2780097    Europe    70.420  3630.880722     1989
# 19  Albania  1987     3075321    Europe    72.000  3738.932735     1994
# 20  Albania  1992     3326498    Europe    71.581  2497.437901     1999
# 21  Albania  1997     3428038    Europe    72.950  3193.054604     2004
#
#              gdp
# 15  5.476396e+09
# 16  7.500110e+09
# 17  8.864476e+09
# 18  1.009420e+10
# 19  1.149842e+10
# 20  8.307722e+09
# 21  1.094591e+10

# %%
sample
# Out:
#        Country  year  population continent  life_exp     gdp_cap  years+7  \
# q  Afghanistan  1952     8425333      Asia    28.801  779.445314     1959
# w  Afghanistan  1957     9240934      Asia    30.332  820.853030     1964
# e  Afghanistan  1962    10267083      Asia    31.997  853.100710     1969
# r  Afghanistan  1967    11537966      Asia    34.020  836.197138     1974
# t  Afghanistan  1972    13079460      Asia    36.088  739.981106     1979
#
#             gdp
# q  6.567086e+09
# w  7.585449e+09
# e  8.758856e+09
# r  9.648014e+09
# t  9.678553e+09

# %%
sample.index[1]
# Out:
# 'w'

# %%
demo = pd.Series(['a','b','c','d','e'], index=[1,5,3,7,3])
demo
# Out:
# 1    a
# 5    b
# 3    c
# 7    d
# 3    e
# dtype: object

# %%
df.loc[9::-3]
# Out:
#        Country  year  population continent  life_exp     gdp_cap  years+7  \
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351     2004
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439     1989
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138     1974
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314     1959
#
#             gdp
# 9  1.412200e+10
# 6  1.259856e+10
# 3  9.648014e+09
# 0  6.567086e+09

# %% [markdown]
# impicit indexing in row

# %%
df.iloc[0]
# Out:
# Country             Afghanistan
# year                       1952
# population              8425333
# continent                  Asia
# life_exp                 28.801
# gdp_cap              779.445314
# years+7                    1959
# gdp           6567086329.952229
# Name: 0, dtype: object

# %%
df.iloc[0:2]
# Out:
#        Country  year  population continent  life_exp     gdp_cap  years+7  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314     1959
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030     1964
#
#             gdp
# 0  6.567086e+09
# 1  7.585449e+09

# %%
listOfIndex = [1,10,100]
df.iloc[listOfIndex]
# Out:
#          Country  year  population continent  life_exp     gdp_cap  years+7  \
# 1    Afghanistan  1957     9240934      Asia    30.332  820.853030     1964
# 10   Afghanistan  2002    25268405      Asia    42.129  726.734055     2009
# 100   Bangladesh  1972    70759295      Asia    45.252  630.233627     1979
#
#               gdp
# 1    7.585449e+09
# 10   1.836341e+10
# 100  4.459489e+10

# %%
df.iloc[-1]
# Out:
# Country                Zimbabwe
# year                       2007
# population             12311143
# continent                Africa
# life_exp                 43.487
# gdp_cap              469.709298
# years+7                    2014
# gdp           5782658337.338729
# Name: 1703, dtype: object

# %%
temp = df.set_index('Country')
temp
# Out:
#              year  population continent  life_exp     gdp_cap  years+7  \
# Country
# Afghanistan  1952     8425333      Asia    28.801  779.445314     1959
# Afghanistan  1957     9240934      Asia    30.332  820.853030     1964
# Afghanistan  1962    10267083      Asia    31.997  853.100710     1969
# Afghanistan  1967    11537966      Asia    34.020  836.197138     1974
# Afghanistan  1972    13079460      Asia    36.088  739.981106     1979
# ...           ...         ...       ...       ...         ...      ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306     1994
# Zimbabwe     1992    10704340    Africa    60.377  693.420786     1999
# Zimbabwe     1997    11404948    Africa    46.809  792.449960     2004
# Zimbabwe     2002    11926563    Africa    39.989  672.038623     2009
# Zimbabwe     2007    12311143    Africa    43.487  469.709298     2014
#
#                       gdp
# Country
# Afghanistan  6.567086e+09
# Afghanistan  7.585449e+09
# ...

# %%
temp.loc['India']
# Out:
#          year  population continent  life_exp      gdp_cap  years+7  \
# Country
# India    1952   372000000      Asia    37.373   546.565749     1959
# India    1957   409000000      Asia    40.249   590.061996     1964
# India    1962   454000000      Asia    43.605   658.347151     1969
# India    1967   506000000      Asia    47.193   700.770611     1974
# India    1972   567000000      Asia    50.651   724.032527     1979
# India    1977   634000000      Asia    54.208   813.337323     1984
# India    1982   708000000      Asia    56.596   855.723538     1989
# India    1987   788000000      Asia    58.553   976.512676     1994
# India    1992   872000000      Asia    60.223  1164.406809     1999
# India    1997   959000000      Asia    61.765  1458.817442     2004
# India    2002  1034172547      Asia    62.879  1746.769454     2009
# India    2007  1110396331      Asia    64.698  2452.210407     2014
#
#                   gdp
# Country
# India    2.033225e+11
# ...

# %%
temp.iloc[1]
# Out:
# year                       1957
# population              9240934
# continent                  Asia
# life_exp                 30.332
# gdp_cap               820.85303
# years+7                    1964
# gdp           7585448670.233646
# Name: Afghanistan, dtype: object

# %%
df.reset_index()
# Out:
#       index      Country  year  population continent  life_exp     gdp_cap  \
# 0         0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1         1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2         2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3         3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4         4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...     ...          ...   ...         ...       ...       ...         ...
# 1699   1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700   1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701   1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702   1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703   1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
#       years+7           gdp
# 0        1959  6.567086e+09
# ...

# %%
df.reset_index(drop = True)
# Out:
#           Country  year  population continent  life_exp     gdp_cap  years+7  \
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314     1959
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030     1964
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710     1969
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138     1974
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106     1979
# ...           ...   ...         ...       ...       ...         ...      ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306     1994
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786     1999
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960     2004
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623     2009
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298     2014
#
#                gdp
# 0     6.567086e+09
# ...

# %%
a = pd.Series(['a','b','c'], index=[1,2,2])
print(a[2])
# Out:
# 2    b
# 2    c
# dtype: object
